# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as ply
import seaborn as sns
# %matplotlib inline

# %%
# Import data and convert to csv, then print

data = pd.read_excel('contributions.xlsx', index_col=0)
data.to_csv('contributions.csv', encoding='utf-8')
data
# Out:
#                          Nomination Year President     Country Confirmed  \
# Name
# Arthur W. Hummel, Jr.               1981    Reagan       China       Yes
# Thomas R. Pickering                 1981    Reagan     Nigeria       Yes
# Robert Strausz-Hupe                 1981    Reagan      Turkey       Yes
# William L. Swing                    1981    Reagan     Liberia       Yes
# Robert L. Barry                     1981    Reagan    Bulgaria       Yes
# ...                                  ...       ...         ...       ...
# John Rakolta                        2018     Trump         UAE       NaN
# Kenn George                         2018     Trump     Uruguay       NaN
# Daniel Rosenblum                    2018     Trump  Uzbekistan       NaN
# Christopher Paul Henzel             2018     Trump       Yemen       NaN
# Brian Nichols                       2018     Trump    Zimbabwe       NaN
#
#                            Doc No. Total Personal Contributions by Nominee  \
# Name
# ...

# %%
# Display all table columns, then print

pd.options.display.max_columns = None
data
# Out:
#                          Nomination Year President     Country Confirmed  \
# Name
# Arthur W. Hummel, Jr.               1981    Reagan       China       Yes
# Thomas R. Pickering                 1981    Reagan     Nigeria       Yes
# Robert Strausz-Hupe                 1981    Reagan      Turkey       Yes
# William L. Swing                    1981    Reagan     Liberia       Yes
# Robert L. Barry                     1981    Reagan    Bulgaria       Yes
# ...                                  ...       ...         ...       ...
# John Rakolta                        2018     Trump         UAE       NaN
# Kenn George                         2018     Trump     Uruguay       NaN
# Daniel Rosenblum                    2018     Trump  Uzbekistan       NaN
# Christopher Paul Henzel             2018     Trump       Yemen       NaN
# Brian Nichols                       2018     Trump    Zimbabwe       NaN
#
#                            Doc No. Total Personal Contributions by Nominee  \
# Name
# ...

# %%
# Regex to remove leading/trailing whitespaces and period chars in column headers, then print

data.columns = data.columns.str.strip().str.replace('.', '')
data
# Out:
#                          Nomination Year President     Country Confirmed  \
# Name
# Arthur W. Hummel, Jr.               1981    Reagan       China       Yes
# Thomas R. Pickering                 1981    Reagan     Nigeria       Yes
# Robert Strausz-Hupe                 1981    Reagan      Turkey       Yes
# William L. Swing                    1981    Reagan     Liberia       Yes
# Robert L. Barry                     1981    Reagan    Bulgaria       Yes
# ...                                  ...       ...         ...       ...
# John Rakolta                        2018     Trump         UAE       NaN
# Kenn George                         2018     Trump     Uruguay       NaN
# Daniel Rosenblum                    2018     Trump  Uzbekistan       NaN
# Christopher Paul Henzel             2018     Trump       Yemen       NaN
# Brian Nichols                       2018     Trump    Zimbabwe       NaN
#
#                             Doc No Total Personal Contributions by Nominee  \
# Name
# ...

# %%
# Two different kinds of visualization e.g. bar, pie

# %%
# Remove useless columns, then print

data = data.drop(['Career Background', 'Country Experience', 'Regional Experience', 'Doc No'], axis=1)
data
# Out:
#                          Nomination Year President     Country Confirmed  \
# Name
# Arthur W. Hummel, Jr.               1981    Reagan       China       Yes
# Thomas R. Pickering                 1981    Reagan     Nigeria       Yes
# Robert Strausz-Hupe                 1981    Reagan      Turkey       Yes
# William L. Swing                    1981    Reagan     Liberia       Yes
# Robert L. Barry                     1981    Reagan    Bulgaria       Yes
# ...                                  ...       ...         ...       ...
# John Rakolta                        2018     Trump         UAE       NaN
# Kenn George                         2018     Trump     Uruguay       NaN
# Daniel Rosenblum                    2018     Trump  Uzbekistan       NaN
# Christopher Paul Henzel             2018     Trump       Yemen       NaN
# Brian Nichols                       2018     Trump    Zimbabwe       NaN
#
#                         Total Personal Contributions by Nominee  \
# Name
# ...

# %%
# Clean data to standardize values e.g. 'Not Reported' versus 'Not reported', and round values

data['Total Personal Contributions by Nominee'].apply(np.ceil)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-c4349076cd1d> in <module>
#       1 # Clean data to standardize values e.g. 'Not Reported' versus 'Not reported', and round values
#       2
# ----> 3 data['Total Personal Contributions by Nominee'].apply(np.ceil)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4033         with np.errstate(all="ignore"):
#    4034             if isinstance(f, np.ufunc):
# -> 4035                 return f(self)
#    4036
#    4037             # row-wise access
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#     851
#     852         inputs = tuple(extract_array(x, extract_numpy=True) for x in inputs)
# --> 853         result = getattr(ufunc, method)(*inputs, **kwargs)
# ...

# %%
data['Total Personal Contributions by Nominee'].value_counts()
