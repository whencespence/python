# %%
pd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2337d7da5ae8> in <module>
# ----> 1 pd
#
# NameError: name 'pd' is not defined

# %%
data

# %%
import pandas as pd

# %%
# read csv file with pandas
data = pd.read_csv('cars.csv')

# %%
data

# %%
products = pd.read_csv('products-2.csv')

# %%
products

# %%
products.describe()

# %%
products = pd.read_csv('product-2.csv')

# %%
products = pd.read_csv('products-2.csv', sep=';')

# %%
products

# %%
products = pd.read_csv('products-2.csv', 'rb')

# %%
products1 = pd.read_csv('products-2.csv', sep = ',')

# %%
products

# %%
products1 = pd.read_csv('products-2.csv', sep = ',')

# %%
products1

# %%
products1 = pd.read_csv('products-2.csv', sep = ',', header=0)

# %%
products1

# %%
products1 = pd.read_csv('products-2.csv', sep = ',', header=0)

# %%
products1

# %%
products1.columns

# %%
products3 = pd.read_csv('products-2.csv')

# %%
products3

# %%
products3.head()

# %%
products3 = pd.read_csv('products-2.csv', delimiter = ',')

# %%
products3

# %%
products3 = pd.read_csv('products-2.csv')

# %%
print(products3)

# %%
products = pd.read_csv('products-2.csv')

# %%
products

# %%
products = pd.read_csv('products-2.csv', sep='\t')

# %%
products

# %%
products.tail()

# %%
black_products = [{'productID','color','name'}]

# %%
black_products

# %%
# list productId, name and reorderpoint of all the productswith listprice greater than 500

# %%
products.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e1f67c01c8d8> in <module>
# ----> 1 products.value_counts()
#
# NameError: name 'products' is not defined

# %%
products['Color']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-44e1ba2f0ebf> in <module>
# ----> 1 products['Color']
#
# NameError: name 'products' is not defined

# %%
import pandas as pd

# %%
products = pd.read_csv('products-2.csv')

# %%
products
# Out:
#     ProductID\tName\tProductNumber\tMakeFlag\tFinishedGoodsFlag\tColor\tSafetyStockLevel\tReorderPoint\tStandardCost\tListPrice\tSize\tSizeUnitMeasureCode\tWeightUnitMeasureCode\tWeight\tDaysToManufacture\tProductLine\tClass\tStyle\tProductSubcategoryID\tProductModelID\tSellStartDate\tSellEndDate\tDiscontinuedDate\trowguid\tModifiedDate
# 0    1\tAdjustable Race\tAR-5381\t0\t0\t\t1000\t750...
# 1    2\tBearing Ball\tBA-8327\t0\t0\t\t1000\t750\t0...
# 2    3\tBB Ball Bearing\tBE-2349\t1\t0\t\t800\t600\...
# 3    4\tHeadset Ball Bearings\tBE-2908\t0\t0\t\t800...
# 4    316\tBlade\tBL-2036\t1\t0\t\t800\t600\t0\t0\t\...
# ..                                                 ...
# 499  995\tML Bottom Bracket\tBB-8107\t1\t1\t\t500\t...
# 500  996\tHL Bottom Bracket\tBB-9108\t1\t1\t\t500\t...
# 501  997\tRoad-750 Black 44\tBK-R19B-44\t1\t1\tBlac...
# 502  998\tRoad-750 Black 48\tBK-R19B-48\t1\t1\tBlac...
# 503  999\tRoad-750 Black 52\tBK-R19B-52\t1\t1\tBlac...
#
# [504 rows x 1 columns]

# %%
products = pd.read_csv('products-2.csv', sep = ',', header=0)

# %%
products
# Out:
#     ProductID\tName\tProductNumber\tMakeFlag\tFinishedGoodsFlag\tColor\tSafetyStockLevel\tReorderPoint\tStandardCost\tListPrice\tSize\tSizeUnitMeasureCode\tWeightUnitMeasureCode\tWeight\tDaysToManufacture\tProductLine\tClass\tStyle\tProductSubcategoryID\tProductModelID\tSellStartDate\tSellEndDate\tDiscontinuedDate\trowguid\tModifiedDate
# 0    1\tAdjustable Race\tAR-5381\t0\t0\t\t1000\t750...
# 1    2\tBearing Ball\tBA-8327\t0\t0\t\t1000\t750\t0...
# 2    3\tBB Ball Bearing\tBE-2349\t1\t0\t\t800\t600\...
# 3    4\tHeadset Ball Bearings\tBE-2908\t0\t0\t\t800...
# 4    316\tBlade\tBL-2036\t1\t0\t\t800\t600\t0\t0\t\...
# ..                                                 ...
# 499  995\tML Bottom Bracket\tBB-8107\t1\t1\t\t500\t...
# 500  996\tHL Bottom Bracket\tBB-9108\t1\t1\t\t500\t...
# 501  997\tRoad-750 Black 44\tBK-R19B-44\t1\t1\tBlac...
# 502  998\tRoad-750 Black 48\tBK-R19B-48\t1\t1\tBlac...
# 503  999\tRoad-750 Black 52\tBK-R19B-52\t1\t1\tBlac...
#
# [504 rows x 1 columns]

# %%
products = pd.read_csv('products-2.csv', sep='\t')

# %%
products
# Out:
#      ProductID                   Name ProductNumber  MakeFlag  \
# 0            1        Adjustable Race       AR-5381         0
# 1            2           Bearing Ball       BA-8327         0
# 2            3        BB Ball Bearing       BE-2349         1
# 3            4  Headset Ball Bearings       BE-2908         0
# 4          316                  Blade       BL-2036         1
# ..         ...                    ...           ...       ...
# 499        995      ML Bottom Bracket       BB-8107         1
# 500        996      HL Bottom Bracket       BB-9108         1
# 501        997      Road-750 Black 44    BK-R19B-44         1
# 502        998      Road-750 Black 48    BK-R19B-48         1
# 503        999      Road-750 Black 52    BK-R19B-52         1
#
#      FinishedGoodsFlag  Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0                    0    NaN              1000           750        0.0000
# ...

# %%
products['Color']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#        ...
# 499      NaN
# 500      NaN
# 501    Black
# 502    Black
# 503    Black
# Name: Color, Length: 504, dtype: object

# %%
# How to create a new column
products['DiscountPrice'] = products['ListPrice'] * 0.5

# %%
products
# Out:
#      ProductID                   Name ProductNumber  MakeFlag  \
# 0            1        Adjustable Race       AR-5381         0
# 1            2           Bearing Ball       BA-8327         0
# 2            3        BB Ball Bearing       BE-2349         1
# 3            4  Headset Ball Bearings       BE-2908         0
# 4          316                  Blade       BL-2036         1
# ..         ...                    ...           ...       ...
# 499        995      ML Bottom Bracket       BB-8107         1
# 500        996      HL Bottom Bracket       BB-9108         1
# 501        997      Road-750 Black 44    BK-R19B-44         1
# 502        998      Road-750 Black 48    BK-R19B-48         1
# 503        999      Road-750 Black 52    BK-R19B-52         1
#
#      FinishedGoodsFlag  Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0                    0    NaN              1000           750        0.0000
# ...

# %%
products.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381         0
# 1          2           Bearing Ball       BA-8327         0
# 2          3        BB Ball Bearing       BE-2349         1
# 3          4  Headset Ball Bearings       BE-2908         0
# 4        316                  Blade       BL-2036         1
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0                  0   NaN              1000           750           0.0
# 1                  0   NaN              1000           750           0.0
# 2                  0   NaN               800           600           0.0
# 3                  0   NaN               800           600           0.0
# 4                  0   NaN               800           600           0.0
#
#    ListPrice  ... Class Style ProductSubcategoryID  ProductModelID  \
# 0        0.0  ...   NaN   NaN                  NaN             NaN
# ...

# %%
products
# Out:
#      ProductID                   Name ProductNumber  MakeFlag  \
# 0            1        Adjustable Race       AR-5381         0
# 1            2           Bearing Ball       BA-8327         0
# 2            3        BB Ball Bearing       BE-2349         1
# 3            4  Headset Ball Bearings       BE-2908         0
# 4          316                  Blade       BL-2036         1
# ..         ...                    ...           ...       ...
# 499        995      ML Bottom Bracket       BB-8107         1
# 500        996      HL Bottom Bracket       BB-9108         1
# 501        997      Road-750 Black 44    BK-R19B-44         1
# 502        998      Road-750 Black 48    BK-R19B-48         1
# 503        999      Road-750 Black 52    BK-R19B-52         1
#
#      FinishedGoodsFlag  Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0                    0    NaN              1000           750        0.0000
# ...

# %%
# Recreate a new column
products['DiscountPrice'] = products['ListPrice'] * 0.5

# %%
products
# Out:
#      ProductID                   Name ProductNumber  MakeFlag  \
# 0            1        Adjustable Race       AR-5381         0
# 1            2           Bearing Ball       BA-8327         0
# 2            3        BB Ball Bearing       BE-2349         1
# 3            4  Headset Ball Bearings       BE-2908         0
# 4          316                  Blade       BL-2036         1
# ..         ...                    ...           ...       ...
# 499        995      ML Bottom Bracket       BB-8107         1
# 500        996      HL Bottom Bracket       BB-9108         1
# 501        997      Road-750 Black 44    BK-R19B-44         1
# 502        998      Road-750 Black 48    BK-R19B-48         1
# 503        999      Road-750 Black 52    BK-R19B-52         1
#
#      FinishedGoodsFlag  Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0                    0    NaN              1000           750        0.0000
# ...

# %%
# Remove a column
products.drop(columns=['DiscountPrice'], inplace=True)

# %%
products
# Out:
#      ProductID                   Name ProductNumber  MakeFlag  \
# 0            1        Adjustable Race       AR-5381         0
# 1            2           Bearing Ball       BA-8327         0
# 2            3        BB Ball Bearing       BE-2349         1
# 3            4  Headset Ball Bearings       BE-2908         0
# 4          316                  Blade       BL-2036         1
# ..         ...                    ...           ...       ...
# 499        995      ML Bottom Bracket       BB-8107         1
# 500        996      HL Bottom Bracket       BB-9108         1
# 501        997      Road-750 Black 44    BK-R19B-44         1
# 502        998      Road-750 Black 48    BK-R19B-48         1
# 503        999      Road-750 Black 52    BK-R19B-52         1
#
#      FinishedGoodsFlag  Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0                    0    NaN              1000           750        0.0000
# ...
