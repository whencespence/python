# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#read in the file 'Homicide.csv' and store it in a variable called homicide
data = pd.read_csv('Homicide.csv')

# %%
#how many rows are in the dataset
data
# Out:
#               X          Y  Index_ Event_Unique_ID  Occurrence_year Division  \
# 0    -79.392853  43.685028       1          111878             2004      D53
# 1    -79.234962  43.781536       2          125755             2004      D42
# 2    -79.206894  43.810860       3          136086             2004      D42
# 3    -79.434403  43.670475       4          148623             2004      D13
# 4    -79.203865  43.823543       5          148619             2004      D42
# ...         ...        ...     ...             ...              ...      ...
# 1010 -79.374847  43.660656    1235  GO-20182242344             2018      D51
# 1011 -79.548676  43.701328    1236  GO-20182280579             2018      D23
# 1012 -79.517776  43.759018    1237  GO-20182315055             2018      D31
# 1013 -79.397644  43.644955    1238  GO-20182320758             2018      D14
# 1014 -79.585831  43.750977    1240  GO-20182339244             2018      D23
#
# ...

# %%
#replace the default index with the values of the 'Index_' column
data[data['Homicide_Type'] == 'Shooting'].groupby('Occurrence_year')['Homicide_Type'].count()
# Out:
# Occurrence_year
# 2004    26
# 2005    53
# 2006    29
# 2007    44
# 2008    37
# 2009    37
# 2010    32
# 2011    28
# 2012    34
# 2013    22
# 2014    27
# 2015    26
# 2016    41
# 2017    39
# 2018    51
# Name: Homicide_Type, dtype: int64

# %%
#replace the default index with the values of the 'Index_' column

# %%
#list the types of homicides in the order of their frequency
data.groupby('Occurrence_year')['Homicide_Type'].count().sort_values(ascending=False)
# Out:
# Occurrence_year
# 2018    96
# 2007    86
# 2005    80
# 2016    75
# 2008    70
# 2006    70
# 2017    65
# 2010    65
# 2004    64
# 2009    62
# 2015    59
# 2014    58
# 2013    57
# 2012    57
# 2011    51
# Name: Homicide_Type, dtype: int64

# %%
#plot the homicide types and their frequencies on a bar chart

# %%
#find the year with the highest number of shootings
data[data['Homicide_Type'] == 'Shooting'].groupby('Occurrence_year')['Homicide_Type'].count().sort_values(ascending=False)
# Out:
# Occurrence_year
# 2005    53
# 2018    51
# 2007    44
# 2016    41
# 2017    39
# 2009    37
# 2008    37
# 2012    34
# 2010    32
# 2006    29
# 2011    28
# 2014    27
# 2015    26
# 2004    26
# 2013    22
# Name: Homicide_Type, dtype: int64

# %%
#for 2018, list the months with the highest and lowest homicides

#create new column
data['Month'] = pd.DatetimeIndex(data['Occurrence_Date']).month

data
# Out:
#               X          Y  Index_ Event_Unique_ID  Occurrence_year Division  \
# 0    -79.392853  43.685028       1          111878             2004      D53
# 1    -79.234962  43.781536       2          125755             2004      D42
# 2    -79.206894  43.810860       3          136086             2004      D42
# 3    -79.434403  43.670475       4          148623             2004      D13
# 4    -79.203865  43.823543       5          148619             2004      D42
# ...         ...        ...     ...             ...              ...      ...
# 1010 -79.374847  43.660656    1235  GO-20182242344             2018      D51
# 1011 -79.548676  43.701328    1236  GO-20182280579             2018      D23
# 1012 -79.517776  43.759018    1237  GO-20182315055             2018      D31
# 1013 -79.397644  43.644955    1238  GO-20182320758             2018      D14
# 1014 -79.585831  43.750977    1240  GO-20182339244             2018      D23
#
# ...

# %%
#list five safest neighborhoods
data.groupby('Neighbourhood')['Index_'].count().sort_values()
# Out:
# Neighbourhood
# Kingsway South (15)                       1
# Yonge-Eglinton (100)                      1
# Newtonbrook West (36)                     1
# Bayview Woods-Steeles (49)                1
# Runnymede-Bloor West Village (89)         2
#                                          ..
# Rouge (131)                              24
# Malvern (132)                            25
# Moss Park (73)                           26
# Glenfield-Jane Heights (25)              27
# Mount Olive-Silverstone-Jamestown (2)    29
# Name: Index_, Length: 130, dtype: int64

# %%
#which neighborhood had the highest number of stabbings
stabbings = data[data['Homicide_Type'] == 'Stabbing'].groupby('Neighbourhood')['Homicide_Type'].count().sort_values(ascending=False)

stabbings
# Out:
# Neighbourhood
# Downsview-Roding-CFB (26)      8
# South Riverdale (70)           7
# Thorncliffe Park (55)          5
# Woburn (137)                   5
# Glenfield-Jane Heights (25)    5
#                               ..
# Hillcrest Village (48)         1
# Highland Creek (134)           1
# High Park-Swansea (87)         1
# High Park North (88)           1
# Agincourt North (129)          1
# Name: Homicide_Type, Length: 97, dtype: int64

# %%
#(optional)list the homicides by year
#hint - one way to do this is to create new column called year, get the yar from the occurence date,
#then group by your new year column

# %%
import dateutil

# %%
data
# Out:
#               X          Y  Index_ Event_Unique_ID  Occurrence_year Division  \
# 0    -79.392853  43.685028       1          111878             2004      D53
# 1    -79.234962  43.781536       2          125755             2004      D42
# 2    -79.206894  43.810860       3          136086             2004      D42
# 3    -79.434403  43.670475       4          148623             2004      D13
# 4    -79.203865  43.823543       5          148619             2004      D42
# ...         ...        ...     ...             ...              ...      ...
# 1010 -79.374847  43.660656    1235  GO-20182242344             2018      D51
# 1011 -79.548676  43.701328    1236  GO-20182280579             2018      D23
# 1012 -79.517776  43.759018    1237  GO-20182315055             2018      D31
# 1013 -79.397644  43.644955    1238  GO-20182320758             2018      D14
# 1014 -79.585831  43.750977    1240  GO-20182339244             2018      D23
#
# ...

# %%
#Function to convert val to better month format

def get_month_name(val):
    months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sept','Oct','Nov','Dec']
    
    #error checking
    try:
        return months[val - 1]
    except:
        return val

# %%
data['Month'] = pd.Datetime(data['Occurrence_year'])
data
# Out:
#               X          Y  Index_ Event_Unique_ID  Occurrence_year Division  \
# 0    -79.392853  43.685028       1          111878             2004      D53
# 1    -79.234962  43.781536       2          125755             2004      D42
# 2    -79.206894  43.810860       3          136086             2004      D42
# 3    -79.434403  43.670475       4          148623             2004      D13
# 4    -79.203865  43.823543       5          148619             2004      D42
# ...         ...        ...     ...             ...              ...      ...
# 1010 -79.374847  43.660656    1235  GO-20182242344             2018      D51
# 1011 -79.548676  43.701328    1236  GO-20182280579             2018      D23
# 1012 -79.517776  43.759018    1237  GO-20182315055             2018      D31
# 1013 -79.397644  43.644955    1238  GO-20182320758             2018      D14
# 1014 -79.585831  43.750977    1240  GO-20182339244             2018      D23
#
# ...

# %%
data['Month'] = data['Month'].apply(get_month_name)

# %%
#Print bunch of rows
data.head(20)
# Out:
#             X          Y  Index_ Event_Unique_ID  Occurrence_year Division  \
# 0  -79.392853  43.685028       1          111878             2004      D53
# 1  -79.234962  43.781536       2          125755             2004      D42
# 2  -79.206894  43.810860       3          136086             2004      D42
# 3  -79.434403  43.670475       4          148623             2004      D13
# 4  -79.203865  43.823543       5          148619             2004      D42
# 5  -79.508636  43.720917       6          152518             2004      D31
# 6  -79.508980  43.722366       7          172092             2004      D31
# 7  -79.592865  43.743115       8          133635             2004      D23
# 8  -79.227600  43.816269      10          218803             2004      D42
# 9  -79.286728  43.700085      11          200779             2004      D41
# 10 -79.266502  43.808029      12          218585             2004      D42
# ...

# %%
#Try another way to get datetime
data['Month'] = pd.to_datetime(data['Occurrence_Date'])
data
# Out:
#               X          Y  Index_ Event_Unique_ID  Occurrence_year Division  \
# 0    -79.392853  43.685028       1          111878             2004      D53
# 1    -79.234962  43.781536       2          125755             2004      D42
# 2    -79.206894  43.810860       3          136086             2004      D42
# 3    -79.434403  43.670475       4          148623             2004      D13
# 4    -79.203865  43.823543       5          148619             2004      D42
# ...         ...        ...     ...             ...              ...      ...
# 1010 -79.374847  43.660656    1235  GO-20182242344             2018      D51
# 1011 -79.548676  43.701328    1236  GO-20182280579             2018      D23
# 1012 -79.517776  43.759018    1237  GO-20182315055             2018      D31
# 1013 -79.397644  43.644955    1238  GO-20182320758             2018      D14
# 1014 -79.585831  43.750977    1240  GO-20182339244             2018      D23
#
# ...

# %%
data['Month'].describe()
# Out:
# count                          1015
# unique                          853
# top       2018-04-23 04:00:00+00:00
# freq                             10
# first     2004-01-03 05:00:00+00:00
# last      2018-12-21 05:00:00+00:00
# Name: Month, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015 entries, 0 to 1014
# Data columns (total 14 columns):
# X                  1015 non-null float64
# Y                  1015 non-null float64
# Index_             1015 non-null int64
# Event_Unique_ID    1015 non-null object
# Occurrence_year    1015 non-null int64
# Division           1015 non-null object
# Homicide_Type      1015 non-null object
# Occurrence_Date    1015 non-null object
# Hood_ID            1015 non-null int64
# Neighbourhood      1015 non-null object
# Lat                1015 non-null float64
# Long               1015 non-null float64
# ObjectId           1015 non-null int64
# Month              1015 non-null datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(4), int64(4), object(5)
# memory usage: 111.1+ KB
